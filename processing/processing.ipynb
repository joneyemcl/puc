# %% [markdown]
# ## Data processing for PUC
#
# - keep function defs at the top
# - keep variable assignments seperate from function calls
# - outputs go to outputs folder

# %%
# LIBRARIES AND FUNCTIONS

import numpy as np
import os
import pandas as pd

def print_npy_file_contents(file_path):
    """
    This function loads and prints the contents of a specific .npy file.
    
    Parameters:
    file_path (str): The path to the .npy file.
    """
    if not file_path.endswith('.npy'):
        print(f"The file {file_path} is not a .npy file.")
        return
    
    if not os.path.isfile(file_path):
        print(f"The file {file_path} does not exist.")
        return
    
    try:
        data = np.load(file_path, allow_pickle=True)
        print(f"Contents of {file_path}:")
        print(data)
        print("\n")
    except Exception as e:
        print(f"An error occurred while loading {file_path}: {e}")


            
            
def populate_dataframe_from_nested_dict(nested_dict):
    def flatten_dict(d, parent_key='', sep='_'):
        items = []
        for k, v in d.items():
            new_key = f'{parent_key}{sep}{k}' if parent_key else k
            if isinstance(v, dict):
                items.extend(flatten_dict(v, new_key, sep=sep).items())
            else:
                items.append((new_key, v))
        return dict(items)
    
    def nested_dict_to_rows(d, keys=[]):
        if isinstance(d, dict):
            rows = []
            for k, v in d.items():
                rows.extend(nested_dict_to_rows(v, keys + [k]))
            return rows
        else:
            return [keys + [d]]
    
    rows = nested_dict_to_rows(nested_dict)
    
    # Determine the number of columns
    max_depth = max(len(row) for row in rows)
    
    # Pad rows to have the same number of columns
    for row in rows:
        while len(row) < max_depth:
            row.append(None)
    
    # Create the DataFrame
    df = pd.DataFrame(rows)
    
    return df



def create_dataframe(file_path, delimiter, has_headers=True):
    if has_headers:
        df = pd.read_csv(file_path, sep=delimiter)
    else:
        df = pd.read_csv(file_path, sep=delimiter, header=None)
    return df

print("Libraries loaded and functions defined")
# Out:
# Libraries loaded and functions defined

# %%
# show outputs of unit_predictions.npy

print_npy_file_contents("C:/Users/LatimerJ/puc/experiments/outputs/unit_predictions.npy")
# Out:
# Contents of C:/Users/LatimerJ/puc/experiments/outputs/unit_predictions.npy:
# {'arabica_ratings': {'Pint': {'': 'ValueError', '1': {'magnitude': 1, 'unit': 'dimensionless', 'entity': 'unknown'}, '1 kg': {'magnitude': 1, 'unit': 'kilogram', 'entity': 'mass'}, '1.2': {'magnitude': 1.2, 'unit': 'dimensionless', 'entity': 'unknown'}, '100 lbs': {'magnitude': 100, 'unit': 'pound', 'entity': 'mass'}, '1000 M': {'magnitude': 1000, 'unit': 'molar', 'entity': 'substance'}, '1200': {'magnitude': 1200, 'unit': 'dimensionless', 'entity': 'unknown'}, '1200-1800m': 'TypeError', '1250m': {'magnitude': 1250, 'unit': 'meter', 'entity': 'length'}, '1300': {'magnitude': 1300, 'unit': 'dimensionless', 'entity': 'unknown'}, '1300 MSNM': 'UndefinedUnitError', '1320': {'magnitude': 1320, 'unit': 'dimensionless', 'entity': 'unknown'}, '1400': {'magnitude': 1400, 'unit': 'dimensionless', 'entity': 'unknown'}, '1400-1900M': 'TypeError', '1400ft': {'magnitude': 1400, 'unit': 'foot', 'entity': 'length'}, '1450': {'magnitude': 1450, 'unit': 'dimensionless', 'entity': 'unknown'}, '15 kg': {'magnitude': 15, 'unit': 'kilogram', 'entity': 'mass'}, '1500-2000 m': 'TypeError', '1520m-2200m': {'magnitude': -680, 'unit': 'meter', 'entity': 'length'}, '1570-1700': {'magnitude': -130, 'unit': 'dimensionless', 'entity': 'unknown'}, '1600 - 1800 m': 'DefinitionSyntaxError', '1700-2000m': 'TypeError', '1750-1800': {'magnitude': -50, 'unit': 'dimensionless', 'entity': 'unknown'}, '1754': {'magnitude': 1754, 'unit': 'dimensionless', 'entity': 'unknown'}, '1795-1850': {'magnitude': -55, 'unit': 'dimensionless', 'entity': 'unknown'}, '1800': {'magnitude': 1800, 'unit': 'dimensionless', 'entity': 'unknown'}, '1800-2200': {'magnitude': -400, 'unit': 'dimensionless', 'entity': 'unknown'}, '1855-1955': {'magnitude': -100, 'unit': 'dimensionless', 'entity': 'unknown'}, '1950': {'magnitude': 1950, 'unit': 'dimensionless', 'entity': 'unknown'}, '1950-2200': {'magnitude': -250, 'unit': 'dimensionless', 'entity': 'unknown'}, '2': {'magnitude': 2, 'unit': 'dimensionless', 'entity': 'unknown'}, '2 kg': {'magnitude': 2, 'unit': 'kilogram', 'entity': 'mass'}, '2 kg,lbs': 'UndefinedUnitError', '2 lbs': {'magnitude': 2, 'unit': 'pound', 'entity': 'mass'}, '2000 ft': {'magnitude': 2000, 'unit': 'foot', 'entity': 'length'}, '3 lbs': {'magnitude': 3, 'unit': 'pound', 'entity': 'mass'}, '30 kg': {'magnitude': 30, 'unit': 'kilogram', 'entity': 'mass'}, '50 kg': {'magnitude': 50, 'unit': 'kilogram', 'entity': 'mass'}, '6': {'magnitude': 6, 'unit': 'dimensionless', 'entity': 'unknown'}, '60 kg': {'magnitude': 60, 'unit': 'kilogram', 'entity': 'mass'}, '69 kg': {'magnitude': 69, 'unit': 'kilogram', 'entity': 'mass'}, '900-1,500m': 'TypeError', 'Meters above sea level: 1.872': 'UndefinedUnitError', 'Meters above sea level: 1.941': 'UndefinedUnitError', 'Meters above sea level: 1.943': 'UndefinedUnitError', 'Meters above sea level: 2.019': 'UndefinedUnitError', 'Meters above sea level: 2.080': 'UndefinedUnitError', 'Meters above sea level: 2.112': 'UndefinedUnitError'}, 'Quantulum': {'': 'Not Identified', '1': {'magnitude': 1.0, 'unit': 'dimensionless', 'entity': 'dimensionless'}, '1 kg': {'magnitude': 1.0, 'unit': 'kilogram', 'entity': 'mass'}, '1.2': {'magnitude': 1.2, 'unit': 'dimensionless', 'entity': 'dimensionless'}, '100 lbs': {'magnitude': 100.0, 'unit': 'pound-mass', 'entity': 'mass'}, '1000 M': {'magnitude': 1000.0, 'unit': 'metre', 'entity': 'length'}, '1200': {'magnitude': 1200.0, 'unit': 'dimensionless', 'entity': 'dimensionless'}, '1200-1800m': {'magnitude': 1500.0, 'unit': 'metre', 'entity': 'length'}, '1250m': {'magnitude': 1250.0, 'unit': 'metre', 'entity': 'length'}, '1300': {'magnitude': 1300.0, 'unit': 'dimensionless', 'entity': 'dimensionless'}, '1300 MSNM': {'magnitude': 1300.0, 'unit': 'millisecond unk', 'entity': 'unknown'}, '1320': {'magnitude': 1320.0, 'unit': 'dimensionless', 'entity': 'dimensionless'}, '1400': {'magnitude': 1400.0, 'unit': 'dimensionless', 'entity': 'dimensionless'}, '1400-1900M': {'magnitude': 1650.0, 'unit': 'metre', 'entity': ...

# %%
# show outputs of cell_annotations.npy

print_npy_file_contents("C:/Users/LatimerJ/puc/experiments/inputs/cell_annotations.npy")
# Out:
# Contents of C:/Users/LatimerJ/puc/experiments/inputs/cell_annotations.npy:
# {'hes': {'62 L': {'magnitude': 62.0, 'unit': ['liter', 'L', 'litre', 'l']}, '116 L': {'magnitude': 116.0, 'unit': ['liter', 'L', 'litre', 'l']}, '67l': {'magnitude': 67.0, 'unit': ['liter', 'L', 'litre', 'l']}, '120l': {'magnitude': 120.0, 'unit': ['liter', 'L', 'litre', 'l']}, '165l': {'magnitude': 165.0, 'unit': ['liter', 'L', 'litre', 'l']}, '170l': {'magnitude': 170.0, 'unit': ['liter', 'L', 'litre', 'l']}, '194l': {'magnitude': 194.0, 'unit': ['liter', 'L', 'litre', 'l']}, '225l': {'magnitude': 225.0, 'unit': ['liter', 'L', 'litre', 'l']}, '84L': {'magnitude': 84.0, 'unit': ['liter', 'L', 'litre', 'l']}, '90L': {'magnitude': 90.0, 'unit': ['liter', 'L', 'litre', 'l']}, '102L': {'magnitude': 102.0, 'unit': ['liter', 'L', 'litre', 'l']}, '122L': {'magnitude': 122.0, 'unit': ['liter', 'L', 'litre', 'l']}, '130L': {'magnitude': 130.0, 'unit': ['liter', 'L', 'litre', 'l']}, '147L': {'magnitude': 147.0, 'unit': ['liter', 'L', 'litre', 'l']}, '165L': {'magnitude': 165.0, 'unit': ['liter', 'L', 'litre', 'l']}, '181L': {'magnitude': 181.0, 'unit': ['liter', 'L', 'litre', 'l']}, '186L': {'magnitude': 186.0, 'unit': ['liter', 'L', 'litre', 'l']}, '200L': {'magnitude': 200.0, 'unit': ['liter', 'L', 'litre', 'l']}, '212L': {'magnitude': 212.0, 'unit': ['liter', 'L', 'litre', 'l']}, '225L': {'magnitude': 225.0, 'unit': ['liter', 'L', 'litre', 'l']}, '346L': {'magnitude': 346.0, 'unit': ['liter', 'L', 'litre', 'l']}, '130 lts': {'magnitude': 130.0, 'unit': ['liter', 'L', 'litre', 'l']}, '115lts': {'magnitude': 115.0, 'unit': ['liter', 'L', 'litre', 'l']}, '131lts': {'magnitude': 131.0, 'unit': ['liter', 'L', 'litre', 'l']}, '204lts': {'magnitude': 204.0, 'unit': ['liter', 'L', 'litre', 'l']}, '120ltrs': {'magnitude': 120.0, 'unit': ['liter', 'L', 'litre', 'l']}, '135ltrs': {'magnitude': 135.0, 'unit': ['liter', 'L', 'litre', 'l']}, '154Ltrs': {'magnitude': 154.0, 'unit': ['liter', 'L', 'litre', 'l']}, '12LTS': {'magnitude': 12.0, 'unit': ['liter', 'L', 'litre', 'l']}, '62LTS': {'magnitude': 62.0, 'unit': ['liter', 'L', 'litre', 'l']}, '70LTS': {'magnitude': 70.0, 'unit': ['liter', 'L', 'litre', 'l']}, '85LTS': {'magnitude': 85.0, 'unit': ['liter', 'L', 'litre', 'l']}, '118LTS': {'magnitude': 118.0, 'unit': ['liter', 'L', 'litre', 'l']}, '123.5LTS': {'magnitude': 123.5, 'unit': ['liter', 'L', 'litre', 'l']}, '132LTS': {'magnitude': 132.0, 'unit': ['liter', 'L', 'litre', 'l']}, '147LTS': {'magnitude': 147.0, 'unit': ['liter', 'L', '
108.0, 'unit': ['liter', 'L', 'litre', 'l']}, '110 Litres': {'magnitude': 110.0, 'unit': ['liter', 'L', 'litre', 'l']}, '130 Litres': {'magnitude': 130.0, 'unit': ['liter', 'L', 'litre', 'l']}, '140 Litres': {'magnitude': 140.0, 'unit': ['liter', 'L', 'litre', 'l']}, '141 Litres': {'magnitude': 141.0, 'unit': ['liter', 'L', 'litre', ...

# %%
# LOADING DATA

# OMOP NumUnit

numunit_omop = pd.read_csv('processing_inputs/2024_03_numunit_withOMOPtarget.txt')
columns_to_drop = ['numunitid', 'obsval']
numunit_omop = numunit_omop.drop(columns=columns_to_drop, axis=1)

# OMOP NumUnit description columns only

#as df
numunit_omop_desc_only = pd.read_csv('processing_inputs/2024_03_numunit_withOMOPtarget_desc_only.csv')
#as dict
numunit_omop_desc_only_dict = numunit_omop_desc_only[['NumUnit', 'description', 'unit', 'source_code_description']].to_dict('records')


# cell_annotations

cell_annotations = np.load("C:/Users/LatimerJ/puc/experiments/inputs/cell_annotations.npy", allow_pickle=True).item()

# %%
# OMOP NmUnit TO .CSV

numunit_omop_csv = pd.read_csv('processing_inputs/2024_03_numunit_withOMOPtarget.txt')
numunit_omop_csv.to_csv('processing_inputs/2024_03_numunit_withOMOPtarget.csv', index=False)

# %%
# CREATING NEW DICT TO ADD TO .NPY v1


"""

numunit_dict_for_npy = {}

for entry in numunit_omop_desc_only_dict:
    description = entry['description']
    unit = entry['unit']
    source_code_description = entry['source_code_description']
    
    numunit_dict_for_npy[description] = {
        'unit': [unit],
        'source_code_description': source_code_description
    }

cell_annotations['NumUnit'] = numunit_dict_for_npy

np.save('C:/Users/LatimerJ/puc/processing/processing_outputs/updated_cell_annotations.npy', cell_annotations)

"""
# Out:
# "\n\nnumunit_dict_for_npy = {}\n\nfor entry in numunit_omop_desc_only_dict:\n    description = entry['description']\n    unit = entry['unit']\n    source_code_description = entry['source_code_description']\n    \n    numunit_dict_for_npy[description] = {\n        'unit': [unit],\n        'source_code_description': source_code_description\n    }\n\ncell_annotations['NumUnit'] = numunit_dict_for_npy\n\nnp.save('C:/Users/LatimerJ/puc/processing/processing_outputs/updated_cell_annotations.npy', cell_annotations)\n\n"

# %%
# CREATING NEW DICT TO ADD TO .NPY v2


# Initialize the nested dictionary
nested_dict = {"NumUnit": {}}

# Iterate through each row in the DataFrame
for index, row in numunit_omop.iterrows():
    description = row['description']
    source_code_description = row['source_code_description']
    
    # Create the inner dictionary
    inner_dict = {
        "magnitude": "",
        "unit": str(source_code_description)
    }
    
    # Update the outer dictionary
    nested_dict["NumUnit"][description] = inner_dict

# print(nested_dict)

cell_annotations.update(nested_dict)

np.save('C:/Users/LatimerJ/puc/processing/processing_outputs/updated_cell_annotations1554.npy', cell_annotations)

# %%
# EXPORTING UPDATED CELL_ANNOTATIONS TO .CSV

updated_cell_annotations_npy = np.load('C:/Users/LatimerJ/puc/processing/processing_outputs/updated_cell_annotations1554.npy', allow_pickle=True).item()

updated_cell_annotations_df = populate_dataframe_from_nested_dict(updated_cell_annotations_npy)
updated_cell_annotations_df.to_csv('C:/Users/LatimerJ/puc/processing/processing_outputs/updated_cell_annotations1554.csv', index=False)

# %%
# EXPORTING UPDATED EXPERIMENT OUTPUTS TO .CSV

updated_cell_annotations_npy = np.load('C:/Users/LatimerJ/puc/processing/processing_outputs/updated_cell_annotations1554.npy', allow_pickle=True).item()

updated_cell_annotations_df = populate_dataframe_from_nested_dict(updated_cell_annotations_npy)
updated_cell_annotations_df.to_csv('C:/Users/LatimerJ/puc/processing/processing_outputs/updated_cell_annotations1554.csv', index=False)
